# %%
from brainsprite_widget import BrainspriteWidget

BrainspriteWidget('/usr/share/fsl/5.0/data/standard/MNI152_T1_2mm.nii.gz')
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:664: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# ...
